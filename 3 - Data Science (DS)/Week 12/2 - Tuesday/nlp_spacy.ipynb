# %% [markdown]
# # Natural Language Processing (NLP) with SpaCy

# %% [markdown]
# spaCy is a Python natural language processing library specifically designed with the goal of being a useful library for implementing production-ready systems. It is particularly fast and intuitive, making it a top contender for NLP tasks.
#
# https://spacy.io/

# %% [markdown]
# spaCy, as well as its English language model, should have been installed at the start. Below are the commands that are needed to install spaCy. Either type the following commands in powershell or terminal, or directly from the Jupyter Notebook by uncommenting the next two lines.

# %%
# Run this only the first time to install SpaCy and download the models
# !pip install -U spacy
# !python -m spacy download en_core_web_sm

# %% [markdown]
# ## Importing libraries

# %%
import spacy
import pandas as pd 

# Loading the English language trained model
nlp = spacy.load("en_core_web_sm")

# import en_core_web_sm
# nlp = en_core_web_sm.load()

# %% [markdown]
# Let us have a sample text as input.

# %%
text = ("Friends, Romans, countrymen, lend me your ears. I come to bury Julius Caesar, not to praise him."
"The evil that men do lives after them. The good is oft interred with their bones.")

# %% [markdown]
# ### Sentence splitting
# Split the sample text into separate sentences (separated by periods.)

# %%
doc = nlp(text)
for i in doc.sents:
    print(i)
# Out:
# Friends, Romans, countrymen, lend me your ears.
# I come to bury Julius Caesar, not to praise him.
# The evil that men do lives after them.
# The good is oft interred with their bones.

# %% [markdown]
# ### Tokenisation

# %% [markdown]
# Splitting into words

# %%
text = ("Friends, Romans, countrymen, lend me your ears.")
doc = nlp(text)
doc.text.split()
# Out:
# ['Friends,', 'Romans,', 'countrymen,', 'lend', 'me', 'your', 'ears.']

# %% [markdown]
# ### Lemmatisation

# %%
doc = nlp("The dogs saw bats with best stripes hanging upside down by their feet")

for token in doc:
    print(token.text + " --> " + token.lemma_)
# Out:
# The --> the
# dogs --> dog
# saw --> see
# bats --> bat
# with --> with
# best --> good
# stripes --> stripe
# hanging --> hang
# upside --> upside
# down --> down
# by --> by
# their --> their
# feet --> foot

# %% [markdown]
# ### Stop Words

# %%
stopwords = nlp.Defaults.stop_words
print('spaCy has a total of ',len(stopwords), ' stop words.')
print(stopwords)
# Out:
# spaCy has a total of  326  stop words.
# {'re', 'amongst', 'regarding', 'thereby', 'whither', 'three', 'without', 'beside', 'nevertheless', 'thus', 'somehow', 'below', 'one', 'seemed', 'themselves', 'above', 'along', 'its', 'give', 'within', 'up', 'never', 'everyone', '‘ve', 'than', 'off', 'only', 'part', 'noone', 'her', 'any', 'their', 'those', 'are', 'indeed', 'ourselves', 'anyhow', 'sometime', 'myself', 'beforehand', 'because', 'so', 'anyway', 'and', 'his', 'until', '’d', '’s', 'would', 'down', 'yet', 'n’t', 'unless', 'namely', 'per', 'eight', 'make', 'between', 'another', 'well', 'four', 'alone', 'done', 'behind', 'top', '‘s', 'if', 'serious', 'say', 'you', 'us', 'enough', 'then', 'must', 'can', "'m", 'either', 'some', 'were', 'it', 'five', 'our', 'after', 'too', 'why', 'becomes', 'she', 'yourself', '’m', 'meanwhile', 'besides', 'each', 'bottom', 'six', 'at', 'used', 'became', 'for', 'moreover', 'into', 'that', 'they', 'fifteen', 'be', "'s", 'though', 'hereby', "'d", 'therein', 'see', 'not', 'move', 'perhaps', 'hence', 'do', 'seeming', 'very', 'hers', '‘d', 'also', 'ca', 'a', 'latter', 'even', 'as', 'seem', 'the', 'already', 'might', 'show', 'about', 'being', 'next', 'itself', 'where', 'anywhere', 'side', 'although', 'becoming', 'much', 'over', 'while', 'formerly', 'will', 'full', 'now', 'all', 'thereafter', 'he', '‘re', 'via', 'am', 'through', 'among', 'of', 'nowhere', 'wherever', 'more', 'others', 'latterly', 'last', 'been', 'mostly', 'really', 'often', 'rather', 'further', 'by', 'is', 'whole', 'forty', 'front', 'keep', 'amount', 'or', 'nine', 'cannot', 'here', 'two', 'first', 'most', 'him', 'we', "'ll", 'under', 'sixty', 'could', 'this', 'during', 'call', 'several', 'otherwise', 'hundred', 'whereafter', 'ever', '’ll', 'other', 'with', 'less', 'own', 'was', 'using', 'something', 'such', 'together', 'your', 'have', 'every', 'from', 'seems', '‘m', 'ten', 'but', 'put', 'anyone', 'just', 'whereby', 'however', 'least', "'re", 'around', 'always', 'everywhere', 'wherein', 'become', 'almost', 'sometimes', 'except', 'neither', 'whenever', 'on', 'quite', 'still', 'nor', 'name', 'to', 'nobody', 'same', 'toward', 'towards', 'an', 'anything', 'former', 'upon', 'please', 'no', 'whereas', 'yourselves', 'everything', 'doing', 'how', 'what', 'should', 'since', 'in', 'eleven', 'across', 'did', 'ours', 'whom', 'twelve', 'whence', 'before', 'them', 'hereupon', 'thru', 'herein', 'mine', '’re', 'go', 'fifty', 'against', 'had', 'whereupon', 'take', 'twenty', 'hereafter', 'somewhere', 'get', 'both', 'himself', 'onto', 'due', 'there', 'my', 'few', 'third', 'n‘t', 'thereupon', 'out', 'when', 'once', 'afterwards', 'none', 'beyond', 'may', 'back', 'which', 'nothing', 'me', 'made', 'else', 'various', 'many', 'has', "n't", 'these', 'whoever', '‘ll', '’ve', 'empty', 'whose', 'who', 'again', 'whatever', 'throughout', 'yours', 'does', 'therefore', 'herself', 'whether', 'thence', 'someone', 'i', "'ve", 'elsewhere'}

# %% [markdown]
# Remove stop words from text sample

# %%
text = "This is not a good time to talk"
doc = nlp(text)

cleanedtext = []
for item in doc:
    if not item.is_stop:
        cleanedtext.append(item.text)
print(' '.join(cleanedtext))
# Out:
# good time talk

# %% [markdown]
# Check if the word is a stop word or not.

# %%
for token in doc:
    print(f'{token.text:{10}} {token.is_stop:{4}}') 
    # is_stop shows whether it is stopword or now
    # 1 - Yes
    # 0 - No
# Out:
# This          1
# is            1
# not           1
# a             1
# good          0
# time          0
# to            1
# talk          0

# %% [markdown]
# Adding stop words
# Uncomment the following lines to add to remove one or multiple stop words.

# %%
# Adding single token as stopword 
nlp.Defaults.stop_words.add("perfect")

# Adding multiple tokens 
nlp.Defaults.stop_words|={"hot","cold"}

# Removing single token
nlp.Defaults.stop_words.remove("what")
#Removing multiple tokens
nlp.Defaults.stop_words -= {"who", "when"}

# %% [markdown]
# POS Tagging

# %%
doc = nlp("Charles M.H.P. Leclerc wins Monaco F1 GP for Ferrari to delight of home crowd.")
# for token in doc:
pos = [(token.text, token.lemma_, token.pos_, token.tag_, spacy.explain(token.tag_), token.dep_,
            token.shape_, token.is_alpha, token.is_stop) for token in doc]
df = pd.DataFrame(pos, columns=['Text', 'Lemma', 'POS', 'TAG', 'Explain', 'DEP', 'Shape', 'Alpha', 'Stop'])
df
# Out:
#        Text    Lemma    POS  TAG                                    Explain  \
# 0   Charles  Charles  PROPN  NNP                      noun, proper singular
# 1    M.H.P.   M.H.P.  PROPN  NNP                      noun, proper singular
# 2   Leclerc  Leclerc  PROPN  NNP                      noun, proper singular
# 3      wins      win   VERB  VBZ          verb, 3rd person singular present
# 4    Monaco   Monaco  PROPN  NNP                      noun, proper singular
# 5        F1       F1  PROPN  NNP                      noun, proper singular
# 6        GP       GP  PROPN  NNP                      noun, proper singular
# 7       for      for  SCONJ   IN  conjunction, subordinating or preposition
# 8   Ferrari  Ferrari  PROPN  NNP                      noun, proper singular
# 9        to       to   PART   TO                           infinitival "to"
# 10  delight  delight   NOUN   NN                     noun, singular or mass
# 11       of       of    ADP   IN  conjunction, subordinating or preposition
# 12     home     home   NOUN   NN                     noun, singular or mass
# 13    crowd    crowd   NOUN   NN                     noun, singular or mass
# 14        .        .  PUNCT    .          punctuation mark, sentence closer
#
#          DEP   Shape  Alpha   Stop
# 0   compound   Xxxxx   True  False
# 1   compound  X.X.X.  False  False
# 2      nsubj   Xxxxx   True  False
# 3       ROOT    xxxx   True  False
# 4   compound   Xxxxx   True  False
# 5   compound      Xd  False  False
# 6       dobj      XX   True  False
# 7       mark     xxx   True   True
# 8      nsubj   Xxxxx   True  False
# 9        aux      xx   True   True
# 10     advcl    xxxx   True  False
# 11      prep      xx   True   True
# 12  compound    xxxx   True  False
# 13      pobj    xxxx   True  False
# 14     punct       .  False  False

# %%
from spacy import displacy

doc = nlp("Charles M.H.P. Leclerc wins Monaco F1 GP for Ferrari to delight of home crowd.")
# doc = nlp("Emma plays tennis for the U.K.")
displacy.render(doc, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="cc2b1a4434e849a39f8361d43962b607-0" class="displacy" width="2500" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Charles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">M.H.P.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Leclerc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">wins</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Monaco</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">F1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">GP</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Ferrari</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">delight</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">home</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">crowd.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-0" stroke-width="2px" d="M70,352.0 C70,177.0 390.0,177.0 390.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc2b1a4434e849a39f8361d43962b607-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc2b1a4434e849a39f8361d43962b607-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-2" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc2b1a4434e849a39f8361d43962b607-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc2b1a4434e849a39f8361d43962b607-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-4" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc2b1a4434e849a39f8361d43962b607-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,354.0 L937,342.0 953,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-5" stroke-width="2px" d="M595,352.0 C595,177.0 1090.0,177.0 1090.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc2b1a4434e849a39f8361d43962b607-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1090.0,354.0 L1098.0,342.0 1082.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-6" stroke-width="2px" d="M1295,352.0 C1295,89.5 1795.0,89.5 1795.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-cc2b1a4434e849a39f8361d43962b607-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-cc2b1a4434e849a39f8361d43962b607-0-7" st

# %% [markdown]
# Entity

# %%
doc = nlp("Google, headquartered in Mountain View (1600 Amphitheatre Pkwy, Mountain View, CA 940430), \
          unveiled the new Android phone for $999 at the Consumer Electronic Show. \
          Sundar Pichai said in his keynote that users love their new Android phones.")

pos = [(ent.text, ent.start_char, ent.end_char, ent.label, ent.label_, spacy.explain(ent.label_)) for ent in doc.ents]
df = pd.DataFrame(pos, columns=['Text', 'Start', 'End', 'Label index', 'Label', 'Explain'])
df
# Out:
#                            Text  Start  End  Label index     Label  \
# 0                        Google      0    6          383       ORG
# 1                 Mountain View     25   38          384       GPE
# 2                          1600     40   44          397  CARDINAL
# 3                 Mountain View     64   77          384       GPE
# 4                     CA 940430     79   88          383       ORG
# 5                       Android    118  125          383       ORG
# 6                           999    137  140          394     MONEY
# 7  the Consumer Electronic Show    144  172          383       ORG
# 8                       Android    244  251          383       ORG
#
#                                         Explain
# 0       Companies, agencies, institutions, etc.
# 1                     Countries, cities, states
# 2  Numerals that do not fall under another type
# 3                     Countries, cities, states
# 4       Companies, agencies, institutions, etc.
# 5       Companies, agencies, institutions, etc.
# 6               Monetary values, including unit
# 7       Companies, agencies, institutions, etc.
# 8       Companies, agencies, institutions, etc.

# %%
spacy.explain('ORG')
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
displacy.render(doc, style = "ent",jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , headquartered in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mountain View
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1600
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  Amphitheatre Pkwy,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mountain View
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CA 940430
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ),           unveiled the new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  phone for $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     999
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Consumer Electronic Show
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# .           Sundar Pichai said in his keynote that users love their new
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Android
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  phones.</div></span>
